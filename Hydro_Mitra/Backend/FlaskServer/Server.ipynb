# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt


model = YOLO('YoloV8MicroplasticDetection.pt')  


img = './source/micro-plastic.jpg'  # Replace with your image path

# Perform inference
results = model(img)


# Display the image with bounding boxes using OpenCV
annotated_img = results[0].plot()  # Annotate the image with boxes

# Show the image using matplotlib
plt.imshow(cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Hide axes
plt.show()
# Out:
# image 1/1 c:\Users\sumit\Desktop\SIH\FlaskServer\source\micro-plastic.jpg: 640x640 3 fibers, 5 films, 3 fragments, 5 pallets, 501.8ms
# Speed: 8.5ms preprocess, 501.8ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
import cv2
from ultralytics import YOLO


# Load the YOLOv8 model (ensure the .pt file is in the correct path)
model = YOLO('YoloV8PolytheneDetection.pt')  # Change this to your model file path


# Provide the path to your video file
video_path = 'source/plastic.mp4'  # Replace with your video file path
cap = cv2.VideoCapture(video_path)  # Open the video file


# Check if the video file is opened correctly
if not cap.isOpened():
    print("Error: Could not open video file.")
    exit()


while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame or end of video reached.")
        break

    # Run YOLOv8 inference on the frame
    results = model(frame)

    # Convert results to box coordinates and class names
    annotated_frame = results[0].plot()  # Annotated frame with boxes and labels

    # Resize the annotated frame to medium size (e.g., 640x480)
    medium_size = (640, 480)  # Set the desired width and height
    resized_frame = cv2.resize(annotated_frame, medium_size)

    # Display the annotated and resized frame
    cv2.imshow('YOLOv8 Object Detection', resized_frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


# Release the capture and close the OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 Plastics, 260.7ms
# Speed: 1.9ms preprocess, 260.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 270.0ms
# Speed: 3.0ms preprocess, 270.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 237.3ms
# Speed: 2.0ms preprocess, 237.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 303.1ms
# Speed: 1.0ms preprocess, 303.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Plastics, 342.9ms
# Speed: 2.0ms preprocess, 342.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Plastics, 330.5ms
# Speed: 2.2ms preprocess, 330.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Plastics, 332.3ms
# Speed: 2.0ms preprocess, 332.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Plastics, 301.8ms
# Speed: 1.9ms preprocess, 301.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Plastics, 326.1ms
# Speed: 2.0ms preprocess, 326.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Plastics, 320.5ms
# Speed: 2.0ms preprocess, 320.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Plastics, 309.9ms
# Speed: 3.0ms preprocess, 309.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Plastics, 420.6ms
# Speed: 3.0ms preprocess, 420.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 353.4ms
# Speed: 2.0ms preprocess, 353.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 319.0ms
# Speed: 1.9ms preprocess, 319.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Plastics, 315.4ms
# Speed: 2.0ms preprocess, 315.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Plastics, 384.6ms
# Speed: 2.1ms preprocess, 384.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Plastics, 358.9ms
# Speed: 4.0ms preprocess, 358.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 327.8ms
# Speed: 2.0ms preprocess, 327.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 331.0ms
# Speed: 4.0ms preprocess, 331.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 315.9ms
# Speed: 2.0ms preprocess, 315.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 1 Trash, 314.2ms
# Speed: 2.0ms preprocess, 314.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 1 Trash, 292.0ms
# Speed: 2.0ms preprocess, 292.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 316.2ms
# Speed: 3.6ms preprocess, 316.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 326.8ms
# Speed: 2.0ms preprocess, 326.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 335.0ms
# Speed: 2.0ms preprocess, 335.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 319.3ms
# Speed: 2.2ms preprocess, 319.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 325.8ms
# Speed: 2.5ms preprocess, 325.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 357.7ms
# Speed: 2.0ms preprocess, 357.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 339.0ms
# Speed: 3.0ms preprocess, 339.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 342.8ms
# Speed: 4.0ms preprocess, 342.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic, 306.5ms
# Speed: 2.0ms preprocess, 306.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Plastic,